# %%
from pandas import DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
a = DataFrame([['1:1', 0.9169, 0.9162],
                 ['1:1.5', 0.9184, 0.8916],
                 ['1:2.5', 0.9127, 0.8308],
                 ['1:5', 0.9231, 0.7119]], 
               columns = ['ratio', 'acc', 'f1'])

# %%
plt.figure(figsize=((16,9)))
xs = [i for i, _ in enumerate(a.acc)]
plt.plot(xs, a.acc, 'g-', label='Accuracy')
plt.plot(xs, a.f1, 'r-', label='F1 score')
# plt.axis([0, 4, 0, 1.])
plt.xlabel("Ratio of negative samples to positive")
plt.xticks(xs, a.ratio)
plt.title("Test on amazon data")
plt.legend()
plt.show()

# %%
b = DataFrame([['1:1', 0.7716, 0.7748],
                 ['1:1.5', 0.7731, 0.7566],
                 ['1:2.5', 0.7561, 0.7174],
                 ['1:5', 0.7155, 0.6289]], 
               columns = ['ratio', 'acc', 'f1'])

# %%
plt.figure(figsize=((16,9)))
xs = [i for i, _ in enumerate(b.acc)]
plt.plot(xs, b.acc, 'g-', label='Accuracy')
plt.plot(xs, b.f1, 'r-', label='F1 score')
plt.xlabel("Ratio of negative samples to positive")
plt.xticks(xs, b.ratio)
plt.title("Test on test('rt') data")
plt.legend()
plt.show()
